# %%
import os
import pandas as pd

# %%
data_path = './result/gold_prices/gold_prices_2025_feb.csv'

# %%
data = pd.read_csv(data_path)

# %%
data.head(20)
# Out:
#                            timestamp                gold_type buy_price  \
# 0   2025-02-20T21:25:07.806040+07:00     Vàng miếng SJC 999.9     9,000
# 1   2025-02-20T21:25:08.060630+07:00      Nhẫn Trơn PNJ 999.9     9,040
# 2   2025-02-20T21:25:08.063006+07:00       Vàng Kim Bảo 999.9     9,040
# 3   2025-02-20T21:25:08.098793+07:00  Vàng Phúc Lộc Tài 999.9     9,040
# 4   2025-02-20T21:25:08.119999+07:00      Vàng nữ trang 999.9     8,960
# 5   2025-02-20T21:25:08.136794+07:00        Vàng nữ trang 999     8,951
# 6   2025-02-20T21:25:08.154351+07:00       Vàng nữ trang 9920     8,896
# 7   2025-02-20T21:25:08.158794+07:00         Vàng nữ trang 99     8,878
# 8   2025-02-20T21:25:08.174422+07:00           Vàng 750 (18K)     6,673
# 9   2025-02-20T21:25:08.266370+07:00           Vàng 585 (14K)     5,153
# 10  2025-02-20T21:25:08.274820+07:00           Vàng 416 (10K)     3,596
# 11  2025-02-20T21:25:08.299476+07:00  Vàng PNJ - Phượng Hoàng     9,040
# ...
